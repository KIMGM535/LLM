# %% [markdown]
# # 랭체인 챗봇 만들기
# - LangChain과 ChatOllama 모델을 사용하여 기본적인 챗봇 구현

# %% [markdown]
# ## 필요 라이브러리 설치

# %%
# %pip install langchain langchain-ollama
# Out:
# Requirement already satisfied: langchain in c:\users\user\anaconda3\envs\llm\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-ollama in c:\users\user\anaconda3\envs\llm\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain) (2.11.9)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.47)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.10)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\envs\llm\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\envs\llm\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\envs\llm\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\user\anaconda3\envs\llm\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\envs\llm\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 모델 선언

# %%
from langchain_ollama import ChatOllama
model = ChatOllama(model="deepseek-r1:1.5b") # 자기 설치 버전에 맞게 변경

# %% [markdown]
# ## 첫 번째 대화
# - 딥시크 R1 모델은 <think> </think> 태그 사이에 자신이 해야 할 일을 생각한 후 답변함
# - </think> 이후 메시지만 출력

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

# %%
messages = [
    SystemMessage("너는 사용자를 도와주는 상담사야. 한국어로만 대답해"),
]

# %%
while True:
    user_input = input("사용자: ")

    if user_input == "exit":
        break

    messages.append(
        HumanMessage(user_input)
    )

    response = model.stream(messages) # invoke 대신 stream으로 출력

    # stream 형식으로 출력
    ai_message = None
    for chunk in response:
        print(chunk.content, end="")
        if ai_message is None:
            ai_message = chunk
        else:
            ai_message += chunk
    print('')

    message_only = ai_message.content.strip()
    #message_only = ai_message.content.split("</think>")[1].strip()
    messages.append(AIMessage(message_only))
# Out:
# DeepSeek의 장점은 below과 같이 Several advantages of DeepSeek can be listed:
#
# 1. ** intelligible and Efficient**: Solution that is easy to understand and highly efficient, capable of quickly solving complex problems.
#
# 2. **Explainable AI (XAI)**: Provides explanations for its decisions or actions in a clear and understandable way.
#
# 3. **Cross-Border and Global Collaboration**: Facilitates international communication and collaboration between different regions and countries.
#
# 4. **Scalability**: Handles increasingly larger and more complex tasks, making it suitable for various industries and applications.
#
# 5. **Adaptive Learning**: Continuously improves its performance through experience and data analysis, allowing it to adapt better to new challenges over time.
#
# 6. **Robustness and Reliability**: Performing well even in the face of noise or perturbations, ensuring reliability and stability across different environments.
#
# 7. **Interoperability**: Being compatible with a wide range of systems, tools, and platforms, enabling seamless integration and collaboration between diverse components.
#
# 8. **Cost-Effective**: Offering a cost-effective solution that can scale from small projects to large-scale solutions, reducing the overall investment required for complex tasks.
#
# 9. **Advanced Functionality**: Providing advanced features such as machine learning, natural language processing (NLP), and real-time data analysis, which enhance its capabilities beyond traditional AI systems.
#
# 10. **Versatile Application**: Applicable across a wide range of domains and industries, from industrial automation to customer service, making it highly versatile for different applications.
#
# These are several key advantages that DeepSeek possesses, contributing to its success in various fields and its ability to tackle increasingly complex problems.
